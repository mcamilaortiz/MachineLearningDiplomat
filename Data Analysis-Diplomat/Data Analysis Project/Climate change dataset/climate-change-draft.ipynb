# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def import_climate():
    return pd.read_csv('/kaggle/input/climate-insights-dataset/climate_change_data.csv')

# %%
climate = import_climate()

# %% [markdown]
# Climate Change Pre-Covid, Covid and Post Covid. I want to see if quarentine had any effect on climate change as people were driving a lot less.

# %%
climate

# %%
climate.Country

# %% [markdown]
# | Country  | Locations|   |   |   |
# |----------|----------|---|---|---|
# |          |          |   |   |   |
# |          |          |   |   |   |
# |          |          |   |   |   |

# %%
CC_Countries = climate[['Location','Country']]
CC_Countries

# %%
climate[(climate['Country'] == 'United States of America')].round(2)

# %%
climate[(climate['Country'] == 'Canada')].round(2)

# %% [markdown]
# | Continent  | Countries|   |   |   |
# |------------|----------|---|---|---|
# |            |          |   |   |   |
# |            |          |   |   |   |
# |            |          |   |   |   |

# %% [markdown]
# | Country  | Temp   | Sea Levels  |   |   |
# |----------|--------|-------------|---|---|
# |          |        |             |   |   |
# |          |        |             |   |   |
# |          |        |             |   |   |

# %%
climate[['Country','Temperature','Sea Level Rise']].round(2)

# %% [markdown]
# | Country  | Temp   | CO2 Emissions  |   |   |
# |----------|--------|-----------------|---|---|
# |          |        |                 |   |   |
# |          |        |                 |   |   |
# |          |        |                 |   |   |

# %%
climate[['Country','Temperature','CO2 Emissions']].round(2)

# %% [markdown]
# | Country  | Temp   | Wind Speed      |   |   |
# |----------|--------|-----------------|---|---|
# |          |        |                 |   |   |
# |          |        |                 |   |   |
# |          |        |                 |   |   |

# %%
climate[['Country','Temperature','Wind Speed']].round(2)

# %% [markdown]
# | Country  | Wind Speed | CO2 Emissions  |   |   |
# |----------|------------|-----------------|---|---|
# |          |            |                 |   |   |
# |          |            |                 |   |   |
# |          |            |                 |   |   |

# %%
climate[['Country','Wind Speed','CO2 Emissions']].round(2)

# %% [markdown]
# | Country  | Precipitation | Humidity  |   |   |
# |----------|---------------|-----------|---|---|
# |          |               |           |   |   |
# |          |               |           |   |   |
# |          |               |           |   |   |

# %%
climate[['Country','Precipitation','Humidity']].round(2)

# %% [markdown]
# **Data Type**
# -

# %%
climate.dtypes

# %% [markdown]
# **All Data**
# -

# %%
climate.head().round(2)

# %% [markdown]
# **Columns**
# -
#
# - Date
# - Location
# - Country
# - Temperature
# - CO2 Emmissions
# - Sea Level Rise
# - Percipitation
# - HUmidity
# - Wind Speed

# %%
climate.columns

# %% [markdown]
# **Countries**
# -

# %% [markdown]
# __________________________________________________________

# %% [markdown]
# **North America**
# -

# %%
CC_USA = climate[(climate['Country'] == 'United States of America')].round(2)
CC_USA

# %%
CC_Canada = climate[(climate['Country'] == 'Canada')].round(2)
CC_Canada

# %% [markdown]
# **Centeral America**
# -

# %%
climate[(climate['Country'] == 'Mexico')].round(2)

# %%
climate[(climate['Country'] == 'Belize')].round(2)

# %%
climate[(climate['Country'] == 'Costa Rica')].round(2)

# %%
climate[(climate['Country'] == 'El Salvador')].round(2)

# %%
climate[(climate['Country'] == 'Honduras')].round(2)

# %%
climate[(climate['Country'] == 'Nicaragua')].round(2)

# %%
climate[(climate['Country'] == 'Panama')].round(2)

# %% [markdown]
# **South America**
# -

# %%
climate[(climate['Country'] == 'Argentina')].round(2)

# %%
climate[(climate['Country'] == 'Bolivia')].round(2)

# %%
climate[(climate['Country'] == 'Brazil')].round(2)

# %%
climate[(climate['Country'] == 'Chile')].round(2)

# %%
climate[(climate['Country'] == 'Colombia')].round(2)

# %%
climate[(climate['Country'] == 'Ecuador')].round(2)

# %%
climate[(climate['Country'] == 'Guyana')].round(2)

# %%
climate[(climate['Country'] == 'Paraguay')].round(2)

# %%
climate[(climate['Country'] == 'Peru')].round(2)

# %%
climate[(climate['Country'] == 'Suriname')].round(2)

# %%
climate[(climate['Country'] == 'Uruguay')].round(2)

# %%
climate[(climate['Country'] == 'Venezuela')].round(2)

# %% [markdown]
# **Europe**
# -

# %%
climate[(climate['Country'] == 'Albania')].round(2)

# %%
climate[(climate['Country'] == 'Andorra')].round(2)

# %%
climate[(climate['Country'] == 'Armenia')].round(2)

# %%
climate[(climate['Country'] == 'Austria')].round(2)

# %%
climate[(climate['Country'] == 'Azerbaijan')].round(2)

# %%
climate[(climate['Country'] == 'Belarus')].round(2)

# %%
climate[(climate['Country'] == 'Belgium')].round(2)

# %%
climate[(climate['Country'] == 'Bosnia and Herzegovina')].round(2)

# %%
climate[(climate['Country'] == 'Bulgaria')].round(2)

# %%
climate[(climate['Country'] == 'Croatia')].round(2)

# %%
climate[(climate['Country'] == 'Cyprus')].round(2)

# %%
climate[(climate['Country'] == 'Czechia')].round(2)

# %%
climate[(climate['Country'] == 'Denmark')].round(2)

# %%
climate[(climate['Country'] == 'Estonia')].round(2)

# %%
climate[(climate['Country'] == 'Finland')].round(2)

# %%
climate[(climate['Country'] == 'France')].round(2)

# %%
climate[(climate['Country'] == 'Georgia')].round(2)

# %%
climate[(climate['Country'] == 'Germany')].round(2)

# %%
climate[(climate['Country'] == 'Greece')].round(2)

# %%
climate[(climate['Country'] == 'Hungary')].round(2)

# %%
climate[(climate['Country'] == 'Iceland')].round(2)

# %%
climate[(climate['Country'] == 'Ireland')].round(2)

# %%
climate[(climate['Country'] == 'Italy')].round(2)

# %%
climate[(climate['Country'] == 'Kazakhstan')].round(2)

# %%
climate[(climate['Country'] == 'Kosovo')].round(2)

# %%
climate[(climate['Country'] == 'Latvia')].round(2)

# %%
climate[(climate['Country'] == 'Liechtenstein')].round(2)

# %%
climate[(climate['Country'] == 'Lithuania')].round(2)

# %%
climate[(climate['Country'] == 'Luxembourg')].round(2)

# %%
climate[(climate['Country'] == 'Malta')].round(2)

# %%
climate[(climate['Country'] == 'Moldova')].round(2)

# %%
climate[(climate['Country'] == 'Monaco')].round(2)

# %%
climate[(climate['Country'] == 'Montenegro')].round(2)

# %%
climate[(climate['Country'] == 'Netherlands')].round(2)

# %%
climate[(climate['Country'] == 'North Macedonia')].round(2)

# %%
climate[(climate['Country'] == 'Norway')].round(2)

# %%
climate[(climate['Country'] == 'Poland')].round(2)

# %%
climate[(climate['Country'] == 'Portugal')].round(2)

# %%
climate[(climate['Country'] == 'Romania')].round(2)

# %%
climate[(climate['Country'] == 'Russia')].round(2)

# %%
climate[(climate['Country'] == 'San Marino')].round(2)

# %%
climate[(climate['Country'] == 'Serbia')].round(2)

# %%
climate[(climate['Country'] == 'Slovakia')].round(2)

# %%
climate[(climate['Country'] == 'Slovenia')].round(2)

# %%
climate[(climate['Country'] == 'Spain')].round(2)

# %%
climate[(climate['Country'] == 'Sweden')].round(2)

# %%
climate[(climate['Country'] == 'Switzerland')].round(2)

# %%
climate[(climate['Country'] == 'Turkey')].round(2)

# %%
climate[(climate['Country'] == 'Ukraine')].round(2)

# %%
climate[(climate['Country'] == 'United Kingdom')].round(2)

# %%
climate[(climate['Country'] == 'Vatican')].round(2)

# %% [markdown]
# **Middle East**
# -

# %% [markdown]
# **Australia**
# -

# %%
CC_Australia = climate[(climate['Country'] == 'Australia')].round(2)
CC_Australia

# %%
CC_Australia[['Date','Location','Country','Temperature','CO2 Emissions', 'Sea Level Rise', 'Precipitation', 'Humidity','Wind Speed']] \
.sort_values('Temperature', ascending=False)

# %%
climate[(climate['Country'] == 'New Zealand')].round(2)

# %% [markdown]
# **Asia**
# -

# %% [markdown]
# **Africa**
# -

# %%
climate[(climate['Country'] == 'Algeria')].round(2)

# %%
climate[(climate['Country'] == 'Angola')].round(2)

# %%
climate[(climate['Country'] == 'Benin')].round(2)

# %%
climate[(climate['Country'] == 'Botswana')].round(2)

# %%
climate[(climate['Country'] == 'Burkina')].round(2)

# %%
climate[(climate['Country'] == 'Burundi')].round(2)

# %%
climate[(climate['Country'] == 'Cabo Verde')].round(2)

# %%
climate[(climate['Country'] == 'Cameroon')].round(2)

# %%
climate[(climate['Country'] == 'Centeral African Republic')].round(2)

# %%
climate[(climate['Country'] == 'Chad')].round(2)

# %%
climate[(climate['Country'] == 'Comoros')].round(2)

# %%
climate[(climate['Country'] == 'Congo')].round(2)

# %%
climate[(climate['Country'] == "Cote d'Ivoire")].round(2)

# %%
climate[(climate['Country'] == 'Djibouti')].round(2)

# %%
climate[(climate['Country'] == 'Egypt')].round(2)

# %%
climate[(climate['Country'] == 'Equatiruak Guinea')].round(2)

# %%
climate[(climate['Country'] == 'Eritrea')].round(2)

# %%
climate[(climate['Country'] == 'Eswatini')].round(2)

# %%
climate[(climate['Country'] == 'Ethiopia')].round(2)

# %%
climate[(climate['Country'] == 'Gabon')].round(2)

# %%
climate[(climate['Country'] == 'Gambia')].round(2)

# %%
climate[(climate['Country'] == 'Ghana')].round(2)

# %%
climate[(climate['Country'] == 'Guinea')].round(2)

# %%
climate[(climate['Country'] == 'Guinea-Bissau')].round(2)

# %%
climate[(climate['Country'] == 'Kenya')].round(2)

# %%
climate[(climate['Country'] == 'Lesotho')].round(2)

# %%
climate[(climate['Country'] == 'Liberia')].round(2)

# %%
climate[(climate['Country'] == 'Libya')].round(2)

# %%
climate[(climate['Country'] == 'Madagascar')].round(2)

# %%
climate[(climate['Country'] == 'Malawi')].round(2)

# %%
climate[(climate['Country'] == 'Mali')].round(2)

# %%
climate[(climate['Country'] == 'Mauritania')].round(2)

# %%
climate[(climate['Country'] == 'Mauritius')].round(2)

# %%
climate[(climate['Country'] == 'Morocco')].round(2)

# %%
climate[(climate['Country'] == 'Mozambique')].round(2)

# %%
climate[(climate['Country'] == 'Namibia')].round(2)

# %%
climate[(climate['Country'] == 'Niger')].round(2)

# %%
climate[(climate['Country'] == 'Nigeria')].round(2)

# %%
climate[(climate['Country'] == 'Rwanda')].round(2)

# %%
climate[(climate['Country'] == 'Senegal')].round(2)

# %%
climate[(climate['Country'] == 'Seychelles')].round(2)

# %%
climate[(climate['Country'] == 'Sierra Leon')].round(2)

# %%
climate[(climate['Country'] == 'Somalia')].round(2)

# %%
climate[(climate['Country'] == 'South Africa')].round(2)

# %%
climate[(climate['Country'] == 'South Sudan')].round(2)

# %%
climate[(climate['Country'] == 'Sudan')].round(2)

# %%
climate[(climate['Country'] == 'Tanzania')].round(2)

# %%
climate[(climate['Country'] == 'Togo')].round(2)

# %%
climate[(climate['Country'] == 'Tunisia')].round(2)

# %%
climate[(climate['Country'] == 'Uganda')].round(2)

# %%
climate[(climate['Country'] == 'Zambia')].round(2)

# %%
climate[(climate['Country'] == 'Zimbabwe')].round(2)

# %% [markdown]
# **----------------------------------------------------------------------------------------**

# %%
climate.Country.nunique()

# %%
list(climate.Country.unique())

# %%
climate.Country.describe()

# %%
list(climate.Location.unique())
